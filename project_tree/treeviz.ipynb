# %% [markdown]
# # Parser to convert spark.ml.model.toDebugstring to json format tree

# %% [markdown]
# ## imports

# %%
import json
import pandas as pd
import numpy as np
import ast
import re

# %% [markdown]
# ## Import Vocaubulary from countVectorizer model

# %%
data_vocabulary = pd.read_csv('vocabulary.csv', sep=',')

# %%
vocab = np.array(data_vocabulary.columns)
print(vocab)
# Out:
# ['EDDF' 'KLAX' 'LFPG' ... 'KGYH' 'KCGZ' 'KOCK']

# %%
vocab = vocab.astype(str)

# %%
vocab = np.char.replace(vocab, ' ', '')

# %%
vocab[14]
# Out:
# 'KDFW'

# %% [markdown]
# ## parser 1

# %%
def parse1(lines):
    block = []
    while lines :
        
        if lines[0].startswith('If'):
            bl = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
            block.append({'name':bl, 'children':parse1(lines)})
            
            
            if lines[0].startswith('Else'):
                be = ' '.join(lines.pop(0).split()[1:]).replace('(', '').replace(')', '')
                block.append({'name':be, 'children':parse1(lines)})
        elif not lines[0].startswith(('If','Else')):
            block2 = lines.pop(0)
            block.append({'name':block2})
        else:
            break	
    return block

# Convert Tree to JSON
def tree_json1(tree):
    data = []
    for line in tree.splitlines() : 
        if line.strip():
            line = line.strip()
            data.append(line)
        else : break
        if not line : break
    res = []
    res.append({'name':'Root', 'children':parse1(data[1:])})
    print ('Conversion Success !')
    return res

# %% [markdown]
# ## debug txt to json tree

# %%
debugtxt = """DecisionTreeClassificationModel: uid=DecisionTreeClassifier_d56b94fed0a2, depth=5, numNodes=41, numClasses=2, numFeatures=3159
  If (feature 3 <= 0.5)
   If (feature 9 <= 0.5)
    If (feature 4 <= 11.5)
     If (feature 108 <= 0.5)
      If (feature 31 <= 0.5)
       Predict: 1.0
      Else (feature 31 > 0.5)
       Predict: 0.0
     Else (feature 108 > 0.5)
      If (feature 549 <= 0.5)
       Predict: 0.0
      Else (feature 549 > 0.5)
       Predict: 1.0
    Else (feature 4 > 11.5)
     Predict: 0.0
   Else (feature 9 > 0.5)
    If (feature 533 <= 0.5)
     If (feature 154 <= 0.5)
      Predict: 0.0
     Else (feature 154 > 0.5)
      If (feature 1223 <= 13.5)
       Predict: 0.0
      Else (feature 1223 > 13.5)
       Predict: 1.0
    Else (feature 533 > 0.5)
     If (feature 0 <= 0.5)
      If (feature 9 <= 7.5)
       Predict: 1.0
      Else (feature 9 > 7.5)
       Predict: 0.0
     Else (feature 0 > 0.5)
      Predict: 0.0
  Else (feature 3 > 0.5)
   If (feature 1338 <= 0.5)
    If (feature 398 <= 48.0)
     If (feature 1146 <= 3.5)
      Predict: 0.0
     Else (feature 1146 > 3.5)
      If (feature 41 <= 5.5)
       Predict: 0.0
      Else (feature 41 > 5.5)
       Predict: 1.0
    Else (feature 398 > 48.0)
     If (feature 111 <= 31.5)
      If (feature 23 <= 0.5)
       Predict: 0.0
      Else (feature 23 > 0.5)
       Predict: 1.0
     Else (feature 111 > 31.5)
      Predict: 1.0
   Else (feature 1338 > 0.5)
    If (feature 96 <= 0.5)
     If (feature 884 <= 5.5)
      Predict: 0.0
     Else (feature 884 > 5.5)
      Predict: 1.0
    Else (feature 96 > 0.5)
     If (feature 58 <= 3.5)
      Predict: 0.0
     Else (feature 58 > 3.5)
      Predict: 1.0"""

# %%
tree_json = tree_json1(debugtxt)
# Out:
# Conversion Success !

# %%
tree_json
# Out:
# [{'name': 'Root',
#   'children': [{'name': 'feature 3 <= 0.5',
#     'children': [{'name': 'feature 9 <= 0.5',
#       'children': [{'name': 'feature 4 <= 11.5',
#         'children': [{'name': 'feature 108 <= 0.5',
#           'children': [{'name': 'feature 31 <= 0.5',
#             'children': [{'name': 'Predict: 1.0'}]},
#            {'name': 'feature 31 > 0.5',
#             'children': [{'name': 'Predict: 0.0'}]}]},
#          {'name': 'feature 108 > 0.5',
#           'children': [{'name': 'feature 549 <= 0.5',
#             'children': [{'name': 'Predict: 0.0'}]},
#            {'name': 'feature 549 > 0.5',
#             'children': [{'name': 'Predict: 1.0'}]}]}]},
#        {'name': 'feature 4 > 11.5', 'children': [{'name': 'Predict: 0.0'}]}]},
#      {'name': 'feature 9 > 0.5',
#       'children': [{'name': 'feature 533 <= 0.5',
#         'children': [{'name': 'feature 154 <= 0.5',
#           'children': [{'name': 'Predict: 0.0'}]},
#          {'name': 'feature 154 > 0.5',
#           'children': [{'name': 'feature 1223 <= 13.5',
#             'children': [{'name': 'Predict: 0.0'}]},
#            {'name': 'feature 1223 > 13.5',
#             'children': [{'name': 'Predict: 1.0'}]}]}]},
#        {'name': 'feature 533 > 0.5',
#         'children': [{'name': 'feature 0 <= 0.5',
#           'children': [{'name': 'feature 9 <= 7.5',
#             'children': [{'name': 'Predict: 1.0'}]},
#            {'name': 'feature 9 > 7.5',
#             'children': [{'name': 'Predict: 0.0'}]}]},
#          {'name': 'feature 0 > 0.5',
#           'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#    {'name': 'feature 3 > 0.5',
#     'children': [{'name': 'feature 1338 <= 0.5',
#       'children': [{'name': 'feature 398 <= 48.0',
#         'children': [{'name': 'feature 1146 <= 3.5',
#           'children': [{'name': 'Predict: 0.0'}]},
#          {'name': 'feature 1146 > 3.5',
#           'children': [{'name': 'feature 41 <= 5.5',
#             'children': [{'name': 'Predict: 0.0'}]},
#            {'name': 'feature 41 > 5.5',
#             'children': [{'name': 'Predict: 1.0'}]}]}]},
#        {'name': 'feature 398 > 48.0',
#         'children': [{'name': 'feature 111 <= 31.5',
#           'children': [{'name': 'feature 23 <= 0.5',
#             'children': [{'name': 'Predict: 0.0'}]},
#            {'name': 'feature 23 > 0.5',
#             'children': [{'name': 'Predict: 1.0'}]}]},
#          {'name': 'feature 111 > 31.5',
#           'children': [{'name': 'Predict: 1.0'}]}]}]},
#      {'name': 'feature 1338 > 0.5',
#       'children': [{'name': 'feature 96 <= 0.5',
#         'children': [{'name': 'feature 884 <= 5.5',
#           'children': [{'name': 'Predict: 0.0'}]},
#          {'name': 'feature 884 > 5.5',
#           'children': [{'name': 'Predict: 1.0'}]}]},
#        {'name': 'feature 96 > 0.5',
#         'children': [{'name': 'feature 58 <= 3.5',
#           'children': [{'name': 'Predict: 0.0'}]},
#          {'name': 'feature 58 > 3.5',
#           'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]

# %% [markdown]
# **Important : il faut convertir les ' en " et supprimer les [] au début et à la fin du texte**

# %% [markdown]
# ## Parser with aiport translation

# %%
def parse2(lines, vocab):
    block = []
    while lines:
        if lines[0].startswith('If'):
            bl_tokens = lines.pop(0).split()
            bl = ' '.join(bl_tokens[1:]).replace('(', '').replace(')', '')
            feature_index = int(bl_tokens[-3])
            bl = bl.replace(f'feature {feature_index}', f'#airport {vocab[feature_index]}')
            block.append({'name': bl, 'children': parse2(lines, vocab)})

            if lines[0].startswith('Else'):
                be_tokens = lines.pop(0).split()
                be = ' '.join(be_tokens[1:]).replace('(', '').replace(')', '')
                feature_index = int(be_tokens[-3])
                be = be.replace(f'feature {feature_index}', f'#airport {vocab[feature_index]}')
                block.append({'name': be, 'children': parse2(lines, vocab)})
        elif not lines[0].startswith(('If', 'Else')):
            block2 = lines.pop(0)
            block.append({'name': block2})
        else:
            break
    return block

# Convert Tree to JSON
def tree_json2(tree, vocab):
    data = []
    for line in tree.splitlines():
        if line.strip():
            line = line.strip()
            data.append(line)
        else:
            break
        if not line:
            break
    res = []
    res.append({'name': 'Root', 'children': parse2(data[1:], vocab)})
    print('Conversion Success!')
    return res

# %%
with open('debugString.txt', 'r') as file:
    debugString = file.read()
    file.close()

# %%
debugString
# Out:
# 'DecisionTreeClassificationModel: uid=DecisionTreeClassifier_6185177ffeb0, depth=30, numNodes=13641, numClasses=2, numFeatures=3159\n  If (feature 32 <= 0.5)\n   If (feature 162 <= 1.5)\n    If (feature 41 <= 0.5)\n     If (feature 4 <= 0.5)\n      If (feature 156 <= 0.5)\n       If (feature 11 <= 0.5)\n        If (feature 411 <= 0.5)\n         If (feature 435 <= 0.5)\n          If (feature 3 <= 0.5)\n           If (feature 116 <= 0.5)\n            If (feature 38 <= 0.5)\n             If (feature 163 <= 0.5)\n              If (feature 57 <= 0.5)\n               If (feature 31 <= 3.5)\n                If (feature 436 <= 1.5)\n                 If (feature 623 <= 0.5)\n                  If (feature 168 <= 1.5)\n                   If (feature 127 <= 17.5)\n                    If (feature 187 <= 0.5)\n                     If (feature 316 <= 0.5)\n                      If (feature 16 <= 0.5)\n                       If (feature 5 <= 0.5)\n                        If (feature 471 <= 11.0)\n                         If (feature 172 <= 0.5)\n                          If (feature 6 <= 0.5)\n                           If (feature 207 <= 0.5)\n                            If (feature 170 <= 0.5)\n                             If (feature 245 <= 0.5)\n                              If (feature 62 <= 0.5)\n                               If (feature 286 <= 18.5)\n                                Predict: 1.0\n                               Else (feature 286 > 18.5)\n                                Predict: 0.0\n                              Else (feature 62 > 0.5)\n                               Predict: 0.0\n                             Else (feature 245 > 0.5)\n                              If (feature 1055 <= 0.5)\n                               Predict: 0.0\n                              Else (feature 1055 > 0.5)\n                               If (feature 832 <= 1.5)\n                                Predict: 1.0\n                               Else (feature 832 > 1.5)\n                                Predict: 0.0\n                            Else (feature 170 > 0.5)\n                             If (feature 49 <= 7.5)\n                              If (feature 432 <= 26.5)\n                               Predict: 0.0\n                              Else (feature 432 > 26.5)\n                               If (feature 119 <= 26.5)\n                                Predict: 0.0\n                               Else (feature 119 > 26.5)\n                                Predict: 1.0\n                             Else (feature 49 > 7.5)\n                              Predict: 1.0\n                           Else (feature 207 > 0.5)\n                            Predict: 0.0\n                          Else (feature 6 > 0.5)\n                           If (feature 301 <= 0.5)\n                            If (feature 1157 <= 0.5)\n                             If (feature 155 <= 0.5)\n                              Predict: 0.0\n                             Else (feature 155 > 0.5)\n                              If (feature 15 <= 0.5)\n                               Predict: 0.0\n                              Else (feature 15 > 0.5)\n                               If (feature 87 <= 0.5)\n                                Predict: 0.0\n                               Else (feature 87 > 0.5)\n                                Predict: 1.0\n                            Else (feature 1157 > 0.5)\n                             If (feature 107 <= 0.5)\n                              Predict: 0.0\n                             Else (feature 107 > 0.5)\n                              If (feature 119 <= 0.5)\n                               Predict: 0.0\n                              Else (feature 119 > 0.5)\n                               Predict: 1.0\n                           Else (feature 301 > 0.5)\n                            If (feature 231 <= 1.5)\n                             If (feature 21 <= 1.5)\n                              If (feature 37 <= 1.5)\n               ...

# %%
tree_json_airport = tree_json2(debugString, vocab=vocab)
tree_json_airport
# Out:
# Conversion Success!
# [{'name': 'Root',
#   'children': [{'name': '#airport KMCO <= 0.5',
#     'children': [{'name': '#airport YSSY <= 1.5',
#       'children': [{'name': '#airport KFLL <= 0.5',
#         'children': [{'name': '#airport ZGGG <= 0.5',
#           'children': [{'name': '#airport LHBP <= 0.5',
#             'children': [{'name': '#airport LTFM <= 0.5',
#               'children': [{'name': '#airport GCXO <= 0.5',
#                 'children': [{'name': '#airport VILH <= 0.5',
#                   'children': [{'name': '#airport ZSPD <= 0.5',
#                     'children': [{'name': '#airport EDDH <= 0.5',
#                       'children': [{'name': '#airport SCEL <= 0.5',
#                         'children': [{'name': '#airport LFBO <= 0.5',
#                           'children': [{'name': '#airport VVNB <= 0.5',
#                             'children': [{'name': '#airport MMMX <= 3.5',
#                               'children': [{'name': '#airport VOCB <= 1.5',
#                                 'children': [{'name': '#airport VABP <= 0.5',
#                                   'children': [{'name': '#airport LCLK <= 1.5',
#                                     'children': [{'name': '#airport SBBR <= 17.5',
#                                       'children': [{'name': '#airport VTBD <= 0.5',
#                                         'children': [{'name': '#airport OPKC <= 0.5',
#                                           'children': [{'name': '#airport ZUUU <= 0.5',
#                                             'children': [{'name': '#airport EGLL <= 0.5',
#                                               'children': [{'name': '#airport WIDD <= 11.0',
#                                                 'children': [{'name': '#airport RJTT <= 0.5',
#                                                   'children': [{'name': '#airport UUEE <= 0.5',
#                                                     'children': [{'name': '#airport RPVM <= 0.5',
#                                                       'children': [{'name': '#airport FAOR <= 0.5',
#                                                         'children': [{'name': '#airport HEGN <= 0.5',
#                                                           'children': [{'name': '#airport CYYZ <= 0.5',
#                                                             'children': [{'name': '#airport NZQN <= 18.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport NZQN > 18.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]},
#                                                            {'name': '#airport CYYZ > 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]}]},
#                                                          {'name': '#airport HEGN > 0.5',
#                                                           'children': [{'name': '#airport UIUU <= 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport UIUU > 0.5',
#                                                             'children': [{'name': '#airport UHBB <= 1.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport UHBB > 1.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                                        {'name': '#airport FAOR > 0.5',
#                                                         'children': [{'name': '#airport LFPO <= 7.5',
#                                                           'children': [{'name': '#airport VERC <= 26.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport VERC > 26.5',
#                                                             'children': [{'name': '#airport VOMM <= 26.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport VOMM > 26.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                          {'name': '#airport LFPO > 7.5',
#                                                           'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                      {'name': '#airport RPVM > 0.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]}]},
#                                                    {'name': '#airport UUEE > 0.5',
#                                                     'children': [{'name': '#airport LEZL <= 0.5',
#                                                       'children': [{'name': '#airport HTZA <= 0.5',
#                                                         'children': [{'name': '#airport LPFR <= 0.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport LPFR > 0.5',
#                                                           'children': [{'name': '#airport EDDM <= 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport EDDM > 0.5',
#                                                             'children': [{'name': '#airport LEMG <= 0.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport LEMG > 0.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                                                        {'name': '#airport HTZA > 0.5',
#                                                         'children': [{'name': '#airport VOHS <= 0.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport VOHS > 0.5',
#                                                           'children': [{'name': '#airport VOMM <= 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport VOMM > 0.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                                                      {'name': '#airport LEZL > 0.5',
#                                                       'children': [{'name': '#airport LEIB <= 1.5',
#                                                         'children': [{'name': '#airport LEMD <= 1.5',
#                                                           'children': [{'name': '#airport UUDD <= 1.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport UUDD > 1.5',
#                                                             'children': [{'name': '#airport UKKK <= 0.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport UKKK > 0.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                          {'name': '#airport LEMD > 1.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]},
#                                                        {'name': '#airport LEIB > 1.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                                  {'name': '#airport RJTT > 0.5',
#                                                   'children': [{'name': '#airport RCMQ <= 0.5',
#                                                     'children': [{'name': '#airport VTBS <= 9.5',
#                                                       'children': [{'name': '#airport WAFF <= 28.0',
#                                                         'children': [{'name': '#airport LFPO <= 9.5',
#                                                           'children': [{'name': '#airport RORS <= 26.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport RORS > 26.5',
#                                                             'children': [{'name': '#airport RJFU <= 23.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport RJFU > 23.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                          {'name': '#airport LFPO > 9.5',
#                                                           'children': [{'name': 'Predict: 1.0'}]}]},
#                                                        {'name': '#airport WAFF > 28.0',
#                                                         'children': [{'name': 'Predict: 1.0'}]}]},
#                                                      {'name': '#airport VTBS > 9.5',
#                                                       'children': [{'name': '#airport RKSI <= 9.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport RKSI > 9.5',
#                                                         'children': [{'name': '#airport VHHH <= 18.5',
#                                                           'children': [{'name': '#airport RCTP <= 4.5',
#                                                             'children': [{'name': '#airport URSS <= 9.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport URSS > 9.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]},
#                                                            {'name': '#airport RCTP > 4.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]},
#                                                          {'name': '#airport VHHH > 18.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                                    {'name': '#airport RCMQ > 0.5',
#                                                     'children': [{'name': '#airport RJTT <= 1.5',
#                                                       'children': [{'name': '#airport ROAH <= 9.5',
#                                                         'children': [{'name': '#airport RJOT <= 1.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport RJOT > 1.5',
#                                                           'children': [{'name': '#airport VTSP <= 3.5',
#                                                             'children': [{'name': '#airport VVDN <= 4.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport VVDN > 4.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]},
#                                                            {'name': '#airport VTSP > 3.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                        {'name': '#airport ROAH > 9.5',
#                                                         'children': [{'name': '#airport VTSP <= 1.5',
#                                                           'children': [{'name': '#airport ROAH <= 21.5',
#                                                             'children': [{'name': '#airport VTBS <= 1.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport VTBS > 1.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]},
#                                                            {'name': '#airport ROAH > 21.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]}]},
#                                                          {'name': '#airport VTSP > 1.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                      {'name': '#airport RJTT > 1.5',
#                                                       'children': [{'name': '#airport VDSR <= 3.5',
#                                                         'children': [{'name': '#airport ROIG <= 0.5',
#                                                           'children': [{'name': '#airport VTBS <= 0.5',
#                                                             'children': [{'name': '#airport RJFF <= 13.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport RJFF > 13.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]},
#                                                            {'name': '#airport VTBS > 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]}]},
#                                                          {'name': '#airport ROIG > 0.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]},
#                                                        {'name': '#airport VDSR > 3.5',
#                                                         'children': [{'name': '#airport ZBOW <= 0.5',
#                                                           'children': [{'name': '#airport RJFF <= 12.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport RJFF > 12.5',
#                                                             'children': [{'name': '#airport OOMS <= 0.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport OOMS > 0.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                          {'name': '#airport ZBOW > 0.5',
#                                                           'children': [{'name': '#airport RJFT <= 10.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport RJFT > 10.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]},
#                                                {'name': '#airport WIDD > 11.0',
#                                                 'children': [{'name': '#airport WATT <= 0.5',
#                                                   'children': [{'name': '#airport WARR <= 12.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport WARR > 12.5',
#                                                     'children': [{'name': '#airport WIBB <= 2.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport WIBB > 2.5',
#                                                       'children': [{'name': '#airport WIMM <= 2.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport WIMM > 2.5',
#                                                         'children': [{'name': '#airport WALL <= 0.5',
#                                                           'children': [{'name': '#airport WARR <= 20.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport WARR > 20.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]},
#                                                          {'name': '#airport WALL > 0.5',
#                                                           'children': [{'name': '#airport WIMM <= 24.5',
#                                                             'children': [{'name': '#airport KIAH <= 0.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport KIAH > 0.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]},
#                                                            {'name': '#airport WIMM > 24.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]},
#                                                  {'name': '#airport WATT > 0.5',
#                                                   'children': [{'name': '#airport WAAA <= 3.5',
#                                                     'children': [{'name': '#airport WIPP <= 20.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport WIPP > 20.5',
#                                                       'children': [{'name': '#airport WARR <= 10.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport WARR > 10.5',
#                                                         'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                    {'name': '#airport WAAA > 3.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                              {'name': '#airport EGLL > 0.5',
#                                               'children': [{'name': '#airport OJAI <= 4.5',
#                                                 'children': [{'name': '#airport EGKK <= 1.5',
#                                                   'children': [{'name': '#airport KLAS <= 7.5',
#                                                     'children': [{'name': '#airport MDSD <= 0.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport MDSD > 0.5',
#                                                       'children': [{'name': '#airport SKSP <= 4.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport SKSP > 4.5',
#                                                         'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                    {'name': '#airport KLAS > 7.5',
#                                                     'children': [{'name': '#airport KLAX <= 4.5',
#                                                       'children': [{'name': 'Predict: 1.0'}]},
#                                                      {'name': '#airport KLAX > 4.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                  {'name': '#airport EGKK > 1.5',
#                                                   'children': [{'name': '#airport KBOS <= 8.5',
#                                                     'children': [{'name': '#airport EGGW <= 3.5',
#                                                       'children': [{'name': '#airport KSFO <= 0.5',
#                                                         'children': [{'name': '#airport KBOS <= 0.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport KBOS > 0.5',
#                                                           'children': [{'name': '#airport EGKK <= 30.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport EGKK > 30.5',
#                                                             'children': [{'name': '#airport KJFK <= 1.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport KJFK > 1.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                                        {'name': '#airport KSFO > 0.5',
#                                                         'children': [{'name': '#airport KJFK <= 21.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport KJFK > 21.5',
#                                                           'children': [{'name': '#airport KLAX <= 1.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]},
#                                                            {'name': '#airport KLAX > 1.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                                      {'name': '#airport EGGW > 3.5',
#                                                       'children': [{'name': '#airport LEAL <= 1.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport LEAL > 1.5',
#                                                         'children': [{'name': '#airport EDDM <= 1.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport EDDM > 1.5',
#                                                           'children': [{'name': '#airport EGFF <= 1.5',
#                                                             'children': [{'name': '#airport LEMD <= 10.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport LEMD > 10.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]},
#                                                            {'name': '#airport EGFF > 1.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                                                    {'name': '#airport KBOS > 8.5',
#                                                     'children': [{'name': '#airport KJFK <= 4.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport KJFK > 4.5',
#                                                       'children': [{'name': '#airport EHAM <= 21.5',
#                                                         'children': [{'name': '#airport KSFO <= 9.5',
#                                                           'children': [{'name': '#airport KLAX <= 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport KLAX > 0.5',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]},
#                                                          {'name': '#airport KSFO > 9.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]},
#                                                        {'name': '#airport EHAM > 21.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                                                {'name': '#airport OJAI > 4.5',
#                                                 'children': [{'name': '#airport UBBB <= 0.5',
#                                                   'children': [{'name': '#airport HECA <= 28.5',
#                                                     'children': [{'name': '#airport HLLB <= 2.5',
#                                                       'children': [{'name': '#airport OEDF <= 6.5',
#                                                         'children': [{'name': '#airport LIPZ <= 0.5',
#                                                           'children': [{'name': '#airport HSSS <= 2.5',
#                                                             'children': [{'name': '#airport EHAM <= 3.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport EHAM > 3.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]},
#                                                            {'name': '#airport HSSS > 2.5',
#                                                             'children': [{'name': '#airport ORMM <= 0.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport ORMM > 0.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                          {'name': '#airport LIPZ > 0.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]},
#                                                        {'name': '#airport OEDF > 6.5',
#                                                         'children': [{'name': '#airport OEDF <= 17.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport OEDF > 17.5',
#                                                           'children': [{'name': '#airport OJAI <= 10.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport OJAI > 10.5',
#                                                             'children': [{'name': '#airport OMAA <= 2.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]},
#                                                              {'name': '#airport OMAA > 2.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                                                      {'name': '#airport HLLB > 2.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]}]},
#                                                    {'name': '#airport HECA > 28.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]}]},
#                                                  {'name': '#airport UBBB > 0.5',
#                                                   'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                            {'name': '#airport ZUUU > 0.5',
#                                             'children': [{'name': '#airport ZGHZ <= 3.5',
#                                               'children': [{'name': '#airport EGPD <= 0.5',
#                                                 'children': [{'name': '#airport ZSJH <= 22.5',
#                                                   'children': [{'name': '#airport ZSRZ <= 22.0',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport ZSRZ > 22.0',
#                                                     'children': [{'name': '#airport ZUUU <= 6.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport ZUUU > 6.5',
#                                                       'children': [{'name': '#airport ZBHH <= 20.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport ZBHH > 20.5',
#                                                         'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                                                  {'name': '#airport ZSJH > 22.5',
#                                                   'children': [{'name': '#airport ZBCZ <= 4.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport ZBCZ > 4.5',
#                                                     'children': [{'name': '#airport ZUUU <= 4.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport ZUUU > 4.5',
#                                                       'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                                                {'name': '#airport EGPD > 0.5',
#                                                 'children': [{'name': '#airport ZSTX <= 3.5',
#                                                   'children': [{'name': 'Predict: 0.0'}]},
#                                                  {'name': '#airport ZSTX > 3.5',
#                                                   'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                              {'name': '#airport ZGHZ > 3.5',
#                                               'children': [{'name': '#airport ZYTX <= 1.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport ZYTX > 1.5',
#                                                 'children': [{'name': '#airport ZSYA <= 0.5',
#                                                   'children': [{'name': 'Predict: 0.0'}]},
#                                                  {'name': '#airport ZSYA > 0.5',
#                                                   'children': [{'name': '#airport ZPLJ <= 18.5',
#                                                     'children': [{'name': '#airport ZHLY <= 1.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport ZHLY > 1.5',
#                                                       'children': [{'name': 'Predict: 1.0'}]}]},
#                                                    {'name': '#airport ZPLJ > 18.5',
#                                                     'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]},
#                                          {'name': '#airport OPKC > 0.5',
#                                           'children': [{'name': '#airport OPPS <= 0.5',
#                                             'children': [{'name': '#airport OMAL <= 0.5',
#                                               'children': [{'name': '#airport OJAQ <= 6.5',
#                                                 'children': [{'name': '#airport OBBI <= 0.5',
#                                                   'children': [{'name': '#airport OMAA <= 8.5',
#                                                     'children': [{'name': '#airport LOWS <= 5.5',
#                                                       'children': [{'name': '#airport HSSK <= 0.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport HSSK > 0.5',
#                                                         'children': [{'name': '#airport OEJN <= 10.5',
#                                                           'children': [{'name': '#airport OERK <= 7.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport OERK > 7.5',
#                                                             'children': [{'name': '#airport LTFJ <= 1.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport LTFJ > 1.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                          {'name': '#airport OEJN > 10.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                      {'name': '#airport LOWS > 5.5',
#                                                       'children': [{'name': '#airport OPLA <= 3.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport OPLA > 3.5',
#                                                         'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                    {'name': '#airport OMAA > 8.5',
#                                                     'children': [{'name': '#airport HECA <= 1.5',
#                                                       'children': [{'name': '#airport OEMA <= 0.5',
#                                                         'children': [{'name': '#airport OPIS <= 1.5',
#                                                           'children': [{'name': '#airport UUEE <= 0.5',
#                                                             'children': [{'name': '#airport LGAV <= 0.5',
#                                                               'children': [{'name': 'Predict: 1.0'}]},
#                                                              {'name': '#airport LGAV > 0.5',
#                                                               'children': [{'name': 'Predict: 0.0'}]}]},
#                                                            {'name': '#airport UUEE > 0.5',
#                                                             'children': [{'name': 'Predict: 0.0'}]}]},
#                                                          {'name': '#airport OPIS > 1.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]}]},
#                                                        {'name': '#airport OEMA > 0.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]}]},
#                                                      {'name': '#airport HECA > 1.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]}]}]},
#                                                  {'name': '#airport OBBI > 0.5',
#                                                   'children': [{'name': '#airport VAAH <= 12.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport VAAH > 12.5',
#                                                     'children': [{'name': '#airport OJAI <= 31.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport OJAI > 31.5',
#                                                       'children': [{'name': '#airport OKKK <= 19.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport OKKK > 19.5',
#                                                         'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                                                {'name': '#airport OJAQ > 6.5',
#                                                 'children': [{'name': '#airport LFPG <= 9.5',
#                                                   'children': [{'name': 'Predict: 0.0'}]},
#                                                  {'name': '#airport LFPG > 9.5',
#                                                   'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                              {'name': '#airport OMAL > 0.5',
#                                               'children': [{'name': '#airport LGAV <= 0.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport LGAV > 0.5',
#                                                 'children': [{'name': '#airport FSIA <= 4.5',
#                                                   'children': [{'name': '#airport VCBI <= 8.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport VCBI > 8.5',
#                                                     'children': [{'name': 'Predict: 1.0'}]}]},
#                                                  {'name': '#airport FSIA > 4.5',
#                                                   'children': [{'name': '#airport OKKK <= 2.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport OKKK > 2.5',
#                                                     'children': [{'name': '#airport OMAA <= 19.0',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport OMAA > 19.0',
#                                                       'children': [{'name': '#airport OJAI <= 10.5',
#                                                         'children': [{'name': '#airport HTZA <= 1.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport HTZA > 1.5',
#                                                           'children': [{'name': '#airport OMAA <= 31.0',
#                                                             'children': [{'name': 'Predict: 0.0'}]},
#                                                            {'name': '#airport OMAA > 31.0',
#                                                             'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                        {'name': '#airport OJAI > 10.5',
#                                                         'children': [{'name': '#airport VRMM <= 3.5',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport VRMM > 3.5',
#                                                           'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]}]},
#                                            {'name': '#airport OPPS > 0.5',
#                                             'children': [{'name': '#airport LTDA <= 26.0',
#                                               'children': [{'name': 'Predict: 0.0'}]},
#                                              {'name': '#airport LTDA > 26.0',
#                                               'children': [{'name': '#airport ORER <= 7.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport ORER > 7.5',
#                                                 'children': [{'name': 'Predict: 1.0'}]}]}]}]}]},
#                                        {'name': '#airport VTBD > 0.5',
#                                         'children': [{'name': '#airport OEMA <= 21.5',
#                                           'children': [{'name': 'Predict: 0.0'}]},
#                                          {'name': '#airport OEMA > 21.5',
#                                           'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                      {'name': '#airport SBBR > 17.5',
#                                       'children': [{'name': '#airport SBSI <= 3.5',
#                                         'children': [{'name': '#airport VEPT <= 27.0',
#                                           'children': [{'name': '#airport LETL <= 1.5',
#                                             'children': [{'name': '#airport SKBO <= 1.5',
#                                               'children': [{'name': 'Predict: 0.0'}]},
#                                              {'name': '#airport SKBO > 1.5',
#                                               'children': [{'name': '#airport SBKP <= 7.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport SBKP > 7.5',
#                                                 'children': [{'name': '#airport KMIA <= 0.5',
#                                                   'children': [{'name': '#airport SBJU <= 3.5',
#                                                     'children': [{'name': '#airport SBGO <= 37.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport SBGO > 37.5',
#                                                       'children': [{'name': 'Predict: 1.0'}]}]},
#                                                    {'name': '#airport SBJU > 3.5',
#                                                     'children': [{'name': '#airport SBAR <= 0.5',
#                                                       'children': [{'name': '#airport SKBO <= 2.5',
#                                                         'children': [{'name': 'Predict: 1.0'}]},
#                                                        {'name': '#airport SKBO > 2.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]}]},
#                                                      {'name': '#airport SBAR > 0.5',
#                                                       'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                  {'name': '#airport KMIA > 0.5',
#                                                   'children': [{'name': 'Predict: 0.0'}]}]}]}]},
#                                            {'name': '#airport LETL > 1.5',
#                                             'children': [{'name': '#airport SBEG <= 0.5',
#                                               'children': [{'name': 'Predict: 0.0'}]},
#                                              {'name': '#airport SBEG > 0.5',
#                                               'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                          {'name': '#airport VEPT > 27.0',
#                                           'children': [{'name': 'Predict: 1.0'}]}]},
#                                        {'name': '#airport SBSI > 3.5',
#                                         'children': [{'name': '#airport SBSL <= 13.0',
#                                           'children': [{'name': 'Predict: 0.0'}]},
#                                          {'name': '#airport SBSL > 13.0',
#                                           'children': [{'name': '#airport SBCT <= 36.5',
#                                             'children': [{'name': '#airport SBCY <= 11.5',
#                                               'children': [{'name': 'Predict: 0.0'}]},
#                                              {'name': '#airport SBCY > 11.5',
#                                               'children': [{'name': '#airport SBRJ <= 97.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport SBRJ > 97.5',
#                                                 'children': [{'name': '#airport SBCH <= 0.5',
#                                                   'children': [{'name': '#airport SBGL <= 15.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport SBGL > 15.5',
#                                                     'children': [{'name': '#airport SBSP <= 23.5',
#                                                       'children': [{'name': 'Predict: 0.0'}]},
#                                                      {'name': '#airport SBSP > 23.5',
#                                                       'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                                  {'name': '#airport SBCH > 0.5',
#                                                   'children': [{'name': '#airport SBJP <= 1.5',
#                                                     'children': [{'name': 'Predict: 0.0'}]},
#                                                    {'name': '#airport SBJP > 1.5',
#                                                     'children': [{'name': '#airport SBUL <= 2.5',
#                                                       'children': [{'name': '#airport SBFI <= 2.5',
#                                                         'children': [{'name': 'Predict: 0.0'}]},
#                                                        {'name': '#airport SBFI > 2.5',
#                                                         'children': [{'name': '#airport SBTE <= 13.0',
#                                                           'children': [{'name': 'Predict: 0.0'}]},
#                                                          {'name': '#airport SBTE > 13.0',
# ...
#                           'children': [{'name': '#airport KDFW <= 1.5',
#                             'children': [{'name': '#airport KLAS <= 11.5',
#                               'children': [{'name': 'Predict: 0.0'}]},
#                              {'name': '#airport KLAS > 11.5',
#                               'children': [{'name': '#airport KPHX <= 17.5',
#                                 'children': [{'name': '#airport KMSY <= 2.5',
#                                   'children': [{'name': '#airport KIAD <= 5.5',
#                                     'children': [{'name': 'Predict: 0.0'}]},
#                                    {'name': '#airport KIAD > 5.5',
#                                     'children': [{'name': '#airport KSAT <= 0.5',
#                                       'children': [{'name': 'Predict: 0.0'}]},
#                                      {'name': '#airport KSAT > 0.5',
#                                       'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                  {'name': '#airport KMSY > 2.5',
#                                   'children': [{'name': '#airport KTPA <= 3.5',
#                                     'children': [{'name': '#airport KCLE <= 3.5',
#                                       'children': [{'name': 'Predict: 0.0'}]},
#                                      {'name': '#airport KCLE > 3.5',
#                                       'children': [{'name': 'Predict: 1.0'}]}]},
#                                    {'name': '#airport KTPA > 3.5',
#                                     'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                {'name': '#airport KPHX > 17.5',
#                                 'children': [{'name': '#airport KATL <= 23.5',
#                                   'children': [{'name': 'Predict: 0.0'}]},
#                                  {'name': '#airport KATL > 23.5',
#                                   'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                            {'name': '#airport KDFW > 1.5',
#                             'children': [{'name': 'Predict: 0.0'}]}]}]}]}]},
#                    {'name': '#airport KDSM > 0.5',
#                     'children': [{'name': 'Predict: 0.0'}]}]},
#                  {'name': '#airport KIAH > 1.5',
#                   'children': [{'name': '#airport KMOT <= 0.5',
#                     'children': [{'name': 'Predict: 0.0'}]},
#                    {'name': '#airport KMOT > 0.5',
#                     'children': [{'name': '#airport KMSP <= 7.5',
#                       'children': [{'name': 'Predict: 0.0'}]},
#                      {'name': '#airport KMSP > 7.5',
#                       'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                {'name': '#airport KATL > 29.5',
#                 'children': [{'name': '#airport KMSP <= 5.5',
#                   'children': [{'name': 'Predict: 0.0'}]},
#                  {'name': '#airport KMSP > 5.5',
#                   'children': [{'name': '#airport KPHX <= 14.5',
#                     'children': [{'name': 'Predict: 0.0'}]},
#                    {'name': '#airport KPHX > 14.5',
#                     'children': [{'name': '#airport KRDU <= 0.5',
#                       'children': [{'name': 'Predict: 0.0'}]},
#                      {'name': '#airport KRDU > 0.5',
#                       'children': [{'name': '#airport KDTW <= 4.5',
#                         'children': [{'name': '#airport KSFO <= 16.5',
#                           'children': [{'name': 'Predict: 0.0'}]},
#                          {'name': '#airport KSFO > 16.5',
#                           'children': [{'name': '#airport KSAT <= 3.5',
#                             'children': [{'name': '#airport KPHX <= 28.5',
#                               'children': [{'name': '#airport KPHL <= 8.5',
#                                 'children': [{'name': '#airport KPDX <= 11.5',
#                                   'children': [{'name': 'Predict: 0.0'}]},
#                                  {'name': '#airport KPDX > 11.5',
#                                   'children': [{'name': '#airport KMEM <= 2.5',
#                                     'children': [{'name': 'Predict: 0.0'}]},
#                                    {'name': '#airport KMEM > 2.5',
#                                     'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                {'name': '#airport KPHL > 8.5',
#                                 'children': [{'name': '#airport KSFO <= 33.5',
#                                   'children': [{'name': '#airport KMKE <= 5.5',
#                                     'children': [{'name': '#airport KSFO <= 23.5',
#                                       'children': [{'name': 'Predict: 0.0'}]},
#                                      {'name': '#airport KSFO > 23.5',
#                                       'children': [{'name': 'Predict: 1.0'}]}]},
#                                    {'name': '#airport KMKE > 5.5',
#                                     'children': [{'name': '#airport KTPA <= 26.5',
#                                       'children': [{'name': '#airport KCLT <= 0.5',
#                                         'children': [{'name': 'Predict: 0.0'}]},
#                                        {'name': '#airport KCLT > 0.5',
#                                         'children': [{'name': '#airport KRSW <= 10.5',
#                                           'children': [{'name': '#airport KCLT <= 3.5',
#                                             'children': [{'name': '#airport KPHX <= 15.5',
#                                               'children': [{'name': '#airport KIAD <= 3.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport KIAD > 3.5',
#                                                 'children': [{'name': 'Predict: 1.0'}]}]},
#                                              {'name': '#airport KPHX > 15.5',
#                                               'children': [{'name': 'Predict: 1.0'}]}]},
#                                            {'name': '#airport KCLT > 3.5',
#                                             'children': [{'name': 'Predict: 0.0'}]}]},
#                                          {'name': '#airport KRSW > 10.5',
#                                           'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                      {'name': '#airport KTPA > 26.5',
#                                       'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                  {'name': '#airport KSFO > 33.5',
#                                   'children': [{'name': '#airport KPVD <= 1.5',
#                                     'children': [{'name': 'Predict: 0.0'}]},
#                                    {'name': '#airport KPVD > 1.5',
#                                     'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                              {'name': '#airport KPHX > 28.5',
#                               'children': [{'name': '#airport KLGA <= 8.5',
#                                 'children': [{'name': 'Predict: 0.0'}]},
#                                {'name': '#airport KLGA > 8.5',
#                                 'children': [{'name': '#airport KAUS <= 8.5',
#                                   'children': [{'name': 'Predict: 0.0'}]},
#                                  {'name': '#airport KAUS > 8.5',
#                                   'children': [{'name': '#airport KMSN <= 0.5',
#                                     'children': [{'name': 'Predict: 0.0'}]},
#                                    {'name': '#airport KMSN > 0.5',
#                                     'children': [{'name': '#airport KCLT <= 1.5',
#                                       'children': [{'name': 'Predict: 1.0'}]},
#                                      {'name': '#airport KCLT > 1.5',
#                                       'children': [{'name': '#airport KRDU <= 11.5',
#                                         'children': [{'name': 'Predict: 0.0'}]},
#                                        {'name': '#airport KRDU > 11.5',
#                                         'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]},
#                            {'name': '#airport KSAT > 3.5',
#                             'children': [{'name': 'Predict: 0.0'}]}]}]},
#                        {'name': '#airport KDTW > 4.5',
#                         'children': [{'name': '#airport KMKE <= 15.5',
#                           'children': [{'name': 'Predict: 0.0'}]},
#                          {'name': '#airport KMKE > 15.5',
#                           'children': [{'name': '#airport KCOS <= 2.5',
#                             'children': [{'name': 'Predict: 0.0'}]},
#                            {'name': '#airport KCOS > 2.5',
#                             'children': [{'name': '#airport KRSW <= 11.5',
#                               'children': [{'name': 'Predict: 0.0'}]},
#                              {'name': '#airport KRSW > 11.5',
#                               'children': [{'name': '#airport KIAH <= 11.5',
#                                 'children': [{'name': '#airport KBOI <= 0.5',
#                                   'children': [{'name': 'Predict: 0.0'}]},
#                                  {'name': '#airport KBOI > 0.5',
#                                   'children': [{'name': 'Predict: 1.0'}]}]},
#                                {'name': '#airport KIAH > 11.5',
#                                 'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]}]}]}]},
#              {'name': '#airport KSJC > 0.5',
#               'children': [{'name': '#airport KLGA <= 2.5',
#                 'children': [{'name': 'Predict: 0.0'}]},
#                {'name': '#airport KLGA > 2.5',
#                 'children': [{'name': '#airport KSNA <= 7.5',
#                   'children': [{'name': 'Predict: 0.0'}]},
#                  {'name': '#airport KSNA > 7.5',
#                   'children': [{'name': '#airport KORD <= 11.5',
#                     'children': [{'name': 'Predict: 0.0'}]},
#                    {'name': '#airport KORD > 11.5',
#                     'children': [{'name': '#airport KCOS <= 1.5',
#                       'children': [{'name': 'Predict: 0.0'}]},
#                      {'name': '#airport KCOS > 1.5',
#                       'children': [{'name': '#airport KSLC <= 0.5',
#                         'children': [{'name': 'Predict: 0.0'}]},
#                        {'name': '#airport KSLC > 0.5',
#                         'children': [{'name': '#airport KSAT <= 2.5',
#                           'children': [{'name': '#airport KLGA <= 15.5',
#                             'children': [{'name': 'Predict: 0.0'}]},
#                            {'name': '#airport KLGA > 15.5',
#                             'children': [{'name': 'Predict: 1.0'}]}]},
#                          {'name': '#airport KSAT > 2.5',
#                           'children': [{'name': '#airport KATL <= 6.5',
#                             'children': [{'name': 'Predict: 0.0'}]},
#                            {'name': '#airport KATL > 6.5',
#                             'children': [{'name': '#airport KMEM <= 0.5',
#                               'children': [{'name': '#airport KRSW <= 28.5',
#                                 'children': [{'name': 'Predict: 0.0'}]},
#                                {'name': '#airport KRSW > 28.5',
#                                 'children': [{'name': '#airport KSAT <= 5.5',
#                                   'children': [{'name': 'Predict: 0.0'}]},
#                                  {'name': '#airport KSAT > 5.5',
#                                   'children': [{'name': 'Predict: 1.0'}]}]}]},
#                              {'name': '#airport KMEM > 0.5',
#                               'children': [{'name': '#airport KLAX <= 14.5',
#                                 'children': [{'name': 'Predict: 0.0'}]},
#                                {'name': '#airport KLAX > 14.5',
#                                 'children': [{'name': '#airport KISP <= 0.5',
#                                   'children': [{'name': 'Predict: 0.0'}]},
#                                  {'name': '#airport KISP > 0.5',
#                                   'children': [{'name': '#airport KTTN <= 5.5',
#                                     'children': [{'name': 'Predict: 0.0'}]},
#                                    {'name': '#airport KTTN > 5.5',
#                                     'children': [{'name': '#airport KCLT <= 7.5',
#                                       'children': [{'name': '#airport KTPA <= 9.5',
#                                         'children': [{'name': '#airport KPHL <= 13.5',
#                                           'children': [{'name': 'Predict: 0.0'}]},
#                                          {'name': '#airport KPHL > 13.5',
#                                           'children': [{'name': '#airport KMSY <= 3.5',
#                                             'children': [{'name': 'Predict: 0.0'}]},
#                                            {'name': '#airport KMSY > 3.5',
#                                             'children': [{'name': '#airport KJAX <= 2.5',
#                                               'children': [{'name': '#airport KRDU <= 7.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport KRDU > 7.5',
#                                                 'children': [{'name': 'Predict: 1.0'}]}]},
#                                              {'name': '#airport KJAX > 2.5',
#                                               'children': [{'name': 'Predict: 1.0'}]}]}]}]},
#                                        {'name': '#airport KTPA > 9.5',
#                                         'children': [{'name': '#airport KSNA <= 9.5',
#                                           'children': [{'name': 'Predict: 0.0'}]},
#                                          {'name': '#airport KSNA > 9.5',
#                                           'children': [{'name': '#airport KATL <= 22.5',
#                                             'children': [{'name': '#airport KMCI <= 4.5',
#                                               'children': [{'name': 'Predict: 0.0'}]},
#                                              {'name': '#airport KMCI > 4.5',
#                                               'children': [{'name': '#airport KIAD <= 6.5',
#                                                 'children': [{'name': 'Predict: 0.0'}]},
#                                                {'name': '#airport KIAD > 6.5',
#                                                 'children': [{'name': 'Predict: 1.0'}]}]}]},
#                                            {'name': '#airport KATL > 22.5',
#                                             'children': [{'name': '#airport KCOS <= 2.5',
#                                               'children': [{'name': 'Predict: 0.0'}]},
#                                              {'name': '#airport KCOS > 2.5',
#                                               'children': [{'name': '#airport KONT <= 0.5',
#                                                 'children': [{'name': '#airport KRDU <= 8.5',
#                                                   'children': [{'name': 'Predict: 0.0'}]},
#                                                  {'name': '#airport KRDU > 8.5',
#                                                   'children': [{'name': 'Predict: 1.0'}]}]},
#                                                {'name': '#airport KONT > 0.5',
#                                                 'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]},
#                                      {'name': '#airport KCLT > 7.5',
#                                       'children': [{'name': '#airport KTPA <= 29.5',
#                                         'children': [{'name': 'Predict: 0.0'}]},
#                                        {'name': '#airport KTPA > 29.5',
#                                         'children': [{'name': 'Predict: 1.0'}]}]}]}]}]}]}]}]}]}]}]}]}]}]}]},
#            {'name': '#airport KRFD > 8.5',
#             'children': [{'name': 'Predict: 0.0'}]}]}]}]}]}]}]

# %%
# with open('data.json', 'w') as file:
#     file.write(tree_json_airport)
#     file.close
